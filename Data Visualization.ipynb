# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from seaborn import set_style
import seaborn as sns
from datetime import datetime

set_style("whitegrid")

# %%
data = pd.read_csv('./New_York_Independent_System_Operator_Jan_2022.csv',parse_dates=['date'])

# %%
data.head()
# Out:
#         date  Day-ahead demand forecast  Net generation  Total interchange  \
# 0 2022-01-01                    1739283         1455168            -366759
# 1 2022-01-02                    1827741         1467853            -455630
# 2 2022-01-03                    2139653         1727063            -533803
# 3 2022-01-04                     859357         2125131            -584043
# 4 2022-01-05                    2127166         1657137            -526654
#
#     Demand
# 0  1821927
# 1  1923483
# 2  2260866
# 3  3613710
# 4  2183791

# %%
plt.figure(figsize=(20,8))

plt.plot(data.date, data.Demand/10**6)

plt.xlabel("Date", fontsize=18)
plt.ylabel("Demand (MWh)", fontsize=18)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()

# %%
data.columns
# Out:
# Index(['date', 'Day-ahead demand forecast', 'Net generation',
#        'Total interchange', 'Demand'],
#       dtype='object')

# %%
sns.heatmap(data[['Net generation',
       'Total interchange', 'Demand']].corr())
# Out:
# <AxesSubplot:>
